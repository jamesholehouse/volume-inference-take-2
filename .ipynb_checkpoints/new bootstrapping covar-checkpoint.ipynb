# %% [markdown]
# # Bootstrapping for each replicate

# %% [markdown]
# ## Data analysis: Linear model fit and volume corrected moments

# %%
using Random, Plots, Distributions, StatsBase, DataFrames, CSV, Plots.PlotMeasures
# Out:
# [ Info: Precompiling CSV [336ed68f-0bac-5ca0-87d4-7b16caf5d00b]

# %%
Plots.theme(:dao)
pal = cgrad(:tol_muted);
cpal = [pal[i] for i in 1/7:1/7:1.0]
population_colors = cpal
# Out:
# 7-element Array{RGBA{Float64},1} with eltype RGBA{Float64}:
#  RGBA{Float64}(0.49523809523809526,0.7809523809523811,0.8857142857142857,1.0)
#  RGBA{Float64}(0.20952380952380956,0.6095238095238096,0.48571428571428577,1.0)
#  RGBA{Float64}(0.29523809523809535,0.5238095238095238,0.2,1.0)
#  RGBA{Float64}(0.7523809523809524,0.7142857142857142,0.35238095238095235,1.0)
#  RGBA{Float64}(0.819047619047619,0.5142857142857142,0.4666666666666667,1.0)
#  RGBA{Float64}(0.5714285714285715,0.17142857142857154,0.35238095238095246,1.0)
#  RGBA{Float64}(0.6666666666666666,0.26666666666666666,0.6,1.0)

# %%
df = DataFrame(CSV.File("./mad1WTGFP/FISH_toShare_NoTSlabel_celldata_long_220620_simple_woMad3Outlier_withColDescription.csv"));

# %%
names(df);

# %%
df = df[:,[:gene,:NucleiCount,:Compartment,:CountMethod,:RNAperCell,:Cell_Length_um]]
# Out:
# 148464×6 DataFrame
#     Row │ gene                    NucleiCount  Compartment  CountMethod     RN ⋯
#         │ String31                Int64        String15     String15        Fl ⋯
# ────────┼───────────────────────────────────────────────────────────────────────
#       1 │ cdc13endog                        1  WholeCell    SpotCount          ⋯
#       2 │ cdc13endog                        1  Nucleus      SpotCount
#       3 │ cdc13endog                        1  Cytoplasm    SpotCount
#       4 │ cdc13endog                        1  WholeCell    IntensityCount
#       5 │ cdc13endog                        1  Nucleus      IntensityCount     ⋯
#       6 │ cdc13endog                        1  Cytoplasm    IntensityCount
#       7 │ cdc13endog                        1  WholeCell    HybridCount
#       8 │ cdc13endog                        1  Nucleus      HybridCount
#       9 │ cdc13endog                        1  Cytoplasm    HybridCount        ⋯
#      10 │ cdc13endog                        1  WholeCell    SpotCount
#      11 │ cdc13endog                        1  Nucleus      SpotCount
#    ⋮    │           ⋮                  ⋮            ⋮             ⋮            ⋱
#  148455 │ SPAC2H1001WTymEGFP-hph            1  Cytoplasm    HybridCount
#  148456 │ SPAC2H1001WTymEGFP-hph            1  WholeCell    SpotCount          ⋯
#  148457 │ SPAC2H1001WTymEGFP-hph            1  Nucleus      SpotCount
#  148458 │ SPAC2H1001WTymEGFP-hph            1  Cytoplasm    SpotCount
#  148459 │ SPAC2H1001WTymEGFP-hph            1  WholeCell    IntensityCount
#  148460 │ SPAC2H1001WTymEGFP-hph            1  Nucleus      IntensityCount     ⋯
#  148461 │ SPAC2H1001WTymEGFP-hph            1  Cytoplasm    IntensityCount
#  148462 │ SPAC2H1001WTymEGFP-hph            1  WholeCell    HybridCount
#  148463 │ SPAC2H1001WTymEGFP-hph            1  Nucleus      HybridCount
#  148464 │ SPAC2H1001WTymEGFP-hph            1  Cytoplasm    HybridCount        ⋯
#                                                2 columns and 148443 rows omitted

# %%
# filter NucleiCount = 1
dfa = subset(df,:NucleiCount => n -> n.==1, :CountMethod => m -> m.=="HybridCount")
# make cyto and nuc table separately.
dfcyto = subset(dfa, :Compartment=>c->c.=="Cytoplasm")
dfnuc = subset(dfa, :Compartment=>c->c.=="Nucleus")
# separate the 7 different genes
dfsN = []; dfsC = [];
genes = unique(dfa[!,:gene])
# add each to the vectors
for i in 1:10
    dftempN = subset(dfnuc, :gene=>S->S.==genes[i])
    dftempC = subset(dfcyto, :gene=>S->S.==genes[i])
    push!(dfsN,dftempN)
    push!(dfsC,dftempC)
end

# %%
dfsC = dfsC[[2,3,4,5,6,7,8]] # don't want cdc or SPACs
dfsN = dfsN[[2,3,4,5,6,7,8]] # don't want cdc or SPACs
# Out:
# 7-element Vector{Any}:
#  1382×6 DataFrame
#   Row │ gene       NucleiCount  Compartment  CountMethod  RNAperCell  Cell_Len ⋯
#       │ String31   Int64        String15     String15     Float64     Float64  ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │ mad1endog            1  Nucleus      HybridCount     0.0             8 ⋯
#     2 │ mad1endog            1  Nucleus      HybridCount     0.0             8
#     3 │ mad1endog            1  Nucleus      HybridCount     0.0             9
#     4 │ mad1endog            1  Nucleus      HybridCount     1.0             9
#     5 │ mad1endog            1  Nucleus      HybridCount     0.0             9 ⋯
#     6 │ mad1endog            1  Nucleus      HybridCount     1.0            11
#     7 │ mad1endog            1  Nucleus      HybridCount     1.0            11
#     8 │ mad1endog            1  Nucleus      HybridCount     0.0            10
#     9 │ mad1endog            1  Nucleus      HybridCount     0.0            10 ⋯
#    10 │ mad1endog            1  Nucleus      HybridCount     1.0            11
#    11 │ mad1endog            1  Nucleus      HybridCount     0.0             8
#   ⋮   │     ⋮           ⋮            ⋮            ⋮           ⋮             ⋮  ⋱
#  1373 │ mad1endog            1  Nucleus      HybridCount     0.0            10
#  1374 │ mad1endog            1  Nucleus      HybridCount     0.0             7 ⋯
#  1375 │ mad1endog            1  Nucleus      HybridCount     0.0             8
#  1376 │ mad1endog            1  Nucleus      HybridCount     1.51483         7
#  1377 │ mad1endog            1  Nucleus      HybridCount     0.0             9
#  1378 │ mad1endog            1  Nucleus      HybridCount     0.0             8 ⋯
#  1379 │ mad1endog            1  Nucleus      HybridCount     0.0             8
#  1380 │ mad1endog            1  Nucleus      HybridCount     0.0            10
#  1381 │ mad1endog            1  Nucleus      HybridCount     0.0             8
#  1382 │ mad1endog            1  Nucleus      HybridCount     0.0             8 ⋯
#                                                   1 column and 1361 rows omitted
#  1425×6 DataFrame
#   Row │ gene       NucleiCount  Compartment  CountMethod  RNAperCell  Cell_Len ⋯
#       │ String31   Int64        String15     String15     Float64     Float64  ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │ rpb1endog            1  Nucleus      HybridCount     4.2731          9 ⋯
#     2 │ rpb1endog            1  Nucleus      HybridCount     5.16741         8
#     3 │ rpb1endog            1  Nucleus      HybridCount     2.0            11
#     4 │ rpb1endog            1  Nucleus      HybridCount     3.06518         9
#     5 │ rpb1endog            1  Nucleus      HybridCount     3.47994        10 ⋯
#     6 │ rpb1endog            1  Nucleus      HybridCount     3.53633         9
#     7 │ rpb1endog            1  Nucleus      HybridCount     6.00207         9
#     8 │ rpb1endog            1  Nucleus      HybridCount     3.9432          7
#     9 │ rpb1endog            1  Nucleus      HybridCount     4.0             8 ⋯
#    10 │ rpb1endog            1  Nucleus      HybridCount     2.0             8
#    11 │ rpb1endog            1  Nucleus      HybridCount     2.66675         6
#   ⋮   │     ⋮           ⋮            ⋮            ⋮           ⋮             ⋮  ⋱
#  1416 │ rpb1endog            1  Nucleus      HybridCount     5.09827         8
#  1417 │ rpb1endog            1  Nucleus      HybridCount     1.0             7 ⋯
#  1418 │ rpb1endog            1  Nucleus      HybridCount     3.77311        13
#  1419 │ rpb1endog            1  Nucleus      HybridCount     5.18013        10
#  1420 │ rpb1endog            1  Nucleus      HybridCount     5.79902         8
#  1421 │ rpb1endog            1  Nucleus      HybridCount     3.54434        12 ⋯
#  1422 │ rpb1endog            1  Nucleus      HybridCount     3.0             8
#  1423 │ rpb1endog            1  Nucleus      HybridCount     1.0             9
#  1424 │ rpb1endog            1  Nucleus      HybridCount     4.01537        12
#  1425 │ rpb1endog            1  Nucleus      HybridCount     4.27846         8 ⋯
#                                                   1 column and 1404 rows omitted
#  2155×6 DataFrame
#   Row │ gene          NucleiCount  Compartment  CountMethod  RNAperCell  Cell_ ⋯
#       │ String31      Int64        String15     String15     Float64     Float ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │ mad1WTymEGFP            1  Nucleus      HybridCount         0.0        ⋯
#     2 │ mad1WTymEGFP            1  Nucleus      HybridCount         0.0
#     3 │ mad1WTymEGFP            1  Nucleus      HybridCount         1.0
#     4 │ mad1WTymEGFP            1  Nucleus      HybridCount         0.0
#     5 │ mad1WTymEGFP            1  Nucleus      HybridCount         0.0        ⋯
#     6 │ mad1WTymEGFP            1  Nucleus      HybridCount         0.0
#     7 │ mad1WTymEGFP            1  Nucleus      HybridCount         0.0
#     8 │ mad1WTymEGFP            1  Nucleus      HybridCount         0.0
#     9 │ mad1WTymEGFP            1  Nucleus      HybridCount         0.0        ⋯
#    10 │ mad1WTymEGFP            1  Nucleus      HybridCount         0.0
#    11 │ mad1WTymEGFP            1  Nucleus      HybridCount         0.0
#   ⋮   │      ⋮             ⋮            ⋮            ⋮           ⋮             ⋱
#  2146 │ mad1WTymEGFP            1  Nucleus      HybridCount         0.0
#  2147 │ mad1WTymEGFP            1  Nucleus      HybridCount         0.0        ⋯
#  2148 │ mad1WTymEGFP            1  Nucleus      HybridCount         0.0
#  2149 │ mad1WTymEGFP            1  Nucleus      HybridCount         0.0
#  2150 │ mad1WTymEGFP            1  Nucleus      HybridCount         1.0
#  2151 │ mad1WTymEGFP            1  Nucleus      HybridCount         0.0        ⋯
#  2152 │ mad1WTymEGFP            1  Nucleus      HybridCount         0.0
#  2153 │ mad1WTymEGFP            1  Nucleus      HybridCount         0.0
#  2154 │ mad1WTymEGFP            1  Nucleus      HybridCount         0.0
#  2155 │ mad1WTymEGFP            1  Nucleus      HybridCount         0.0        ⋯
#                                                   1 column and 2134 rows omitted
#  3064×6 DataFrame
#   Row │ gene          NucleiCount  Compartment  CountMethod  RNAperCell  Cell_ ⋯
#       │ String31      Int64        String15     String15     Float64     Float ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │ mad2WTymEGFP            1  Nucleus      HybridCount     1.0            ⋯
#     2 │ mad2WTymEGFP            1  Nucleus      HybridCount     2.0
#     3 │ mad2WTymEGFP            1  Nucleus      HybridCount     1.0
#     4 │ mad2WTymEGFP            1  Nucleus      HybridCount     1.0
#     5 │ mad2WTymEGFP            1  Nucleus      HybridCount     1.0            ⋯
#     6 │ mad2WTymEGFP            1  Nucleus      HybridCount     1.0
#     7 │ mad2WTymEGFP            1  Nucleus      HybridCount     1.0
#     8 │ mad2WTymEGFP            1  Nucleus      HybridCount     1.0
#     9 │ mad2WTymEGFP            1  Nucleus      HybridCount     0.0            ⋯
#    10 │ mad2WTymEGFP            1  Nucleus      HybridCount     0.0
#    11 │ mad2WTymEGFP            1  Nucleus      HybridCount     0.0
#   ⋮   │      ⋮             ⋮            ⋮            ⋮           ⋮             ⋱
#  3055 │ mad2WTymEGFP            1  Nucleus      HybridCount     2.0
#  3056 │ mad2WTymEGFP            1  Nucleus      HybridCount     0.0            ⋯
#  3057 │ mad2WTymEGFP            1  Nucleus      HybridCount     0.0
#  3058 │ mad2WTymEGFP            1  Nucleus      HybridCount     1.0
#  3059 │ mad2WTymEGFP            1  Nucleus      HybridCount     1.0
#  3060 │ mad2WTymEGFP            1  Nucleus      HybridCount     0.0            ⋯
#  3061 │ mad2WTymEGFP            1  Nucleus      HybridCount     1.0
#  3062 │ mad2WTymEGFP            1  Nucleus      HybridCount     0.0
#  3063 │ mad2WTymEGFP            1  Nucleus      HybridCount     1.0
#  3064 │ mad2WTymEGFP            1  Nucleus      HybridCount     2.0            ⋯
#                                                   1 column and 3043 rows omitted
#  1142×6 DataFrame
#   Row │ gene          NucleiCount  Compartment  CountMethod  RNAperCell  Cell_ ⋯
#       │ String31      Int64        String15     String15     Float64     Float ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │ bub1WTymEGFP            1  Nucleus      HybridCount         0.0        ⋯
#     2 │ bub1WTymEGFP            1  Nucleus      HybridCount         0.0
#     3 │ bub1WTymEGFP            1  Nucleus      HybridCount         1.0
#     4 │ bub1WTymEGFP            1  Nucleus      HybridCount         0.0
#     5 │ bub1WTymEGFP            1  Nucleus      HybridCount         2.0        ⋯
#     6 │ bub1WTymEGFP            1  Nucleus      HybridCount         0.0
#     7 │ bub1WTymEGFP            1  Nucleus      HybridCount         0.0
#     8 │ bub1WTymEGFP            1  Nucleus      HybridCount         0.0
#     9 │ bub1WTymEGFP            1  Nucleus      HybridCount         1.0        ⋯
#    10 │ bub1WTymEGFP            1  Nucleus      HybridCount         1.0
#    11 │ bub1WTymEGFP            1  Nucleus      HybridCount         0.0
#   ⋮   │      ⋮             ⋮            ⋮            ⋮           ⋮             ⋱
#  1133 │ bub1WTymEGFP            1  Nucleus      HybridCount         0.0
#  1134 │ bub1WTymEGFP            1  Nucleus      HybridCount         0.0        ⋯
#  1135 │ bub1WTymEGFP            1  Nucleus      HybridCount         0.0
#  1136 │ bub1WTymEGFP            1  Nucleus      HybridCount         0.0
#  1137 │ bub1WTymEGFP            1  Nucleus      HybridCount         1.0
#  1138 │ bub1WTymEGFP            1  Nucleus      HybridCount         1.0        ⋯
#  1139 │ bub1WTymEGFP            1  Nucleus      HybridCount         1.0
#  1140 │ bub1WTymEGFP            1  Nucleus      HybridCount         0.0
#  1141 │ bub1WTymEGFP            1  Nucleus      HybridCount         1.0
#  1142 │ bub1WTymEGFP            1  Nucleus      HybridCount         1.0        ⋯
#                                                   1 column and 1121 rows omitted
#  2660×6 DataFrame
#   Row │ gene          NucleiCount  Compartment  CountMethod  RNAperCell  Cell_ ⋯
#       │ String31      Int64        String15     String15     Float64     Float ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │ mad3WTymEGFP            1  Nucleus      HybridCount     0.0            ⋯
#     2 │ mad3WTymEGFP            1  Nucleus      HybridCount     1.0
#     3 │ mad3WTymEGFP            1  Nucleus      HybridCount     2.12514
#     4 │ mad3WTymEGFP            1  Nucleus      HybridCount     0.0
#     5 │ mad3WTymEGFP            1  Nucleus      HybridCount     0.0            ⋯
#     6 │ mad3WTymEGFP            1  Nucleus      HybridCount     1.0
#     7 │ mad3WTymEGFP            1  Nucleus      HybridCount     1.0
#     8 │ mad3WTymEGFP            1  Nucleus      HybridCount     1.0
#     9 │ mad3WTymEGFP            1  Nucleus      HybridCount     0.0            ⋯
#    10 │ mad3WTymEGFP            1  Nucleus      HybridCount     0.0
#    11 │ mad3WTymEGFP            1  Nucleus      HybridCount     0.0
#   ⋮   │      ⋮             ⋮            ⋮            ⋮           ⋮             ⋱
#  2651 │ mad3WTymEGFP            1  Nucleus      HybridCount     1.0
#  2652 │ mad3WTymEGFP            1  Nucleus      HybridCount     1.45746        ⋯
#  2653 │ mad3WTymEGFP            1  Nucleus      HybridCount     0.0
#  2654 │ mad3WTymEGFP            1  Nucleus      HybridCount     0.0
#  2655 │ mad3WTymEGFP            1  Nucleus      HybridCount     1.0
#  2656 │ mad3WTymEGFP            1  Nucleus      HybridCount     0.0            ⋯
#  2657 │ mad3WTymEGFP            1  Nucleus      HybridCount     0.0
#  2658 │ mad3WTymEGFP            1  Nucleus      HybridCount     0.0
#  2659 │ mad3WTymEGFP            1  Nucleus      HybridCount     1.0
#  2660 │ mad3WTymEGFP            1  Nucleus      HybridCount     1.0            ⋯
#                                                   1 column and 2639 rows omitted
#  589×6 DataFrame
#  Row │ gene              NucleiCount  Compartment  CountMethod  RNAperCell  Ce ⋯
#      │ String31          Int64        String15     String15     Float64     Fl ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ sep1WTymEGFP-hph            1  Nucleus      HybridCount     0.0         ⋯
#    2 │ sep1WTymEGFP-hph            1  Nucleus      HybridCount     3.00521
#    3 │ sep1WTymEGFP-hph            1  Nucleus      HybridCount     4.75095
#    4 │ sep1WTymEGFP-hph            1  Nucleus      HybridCount     0.0
#    5 │ sep1WTymEGFP-hph            1  Nucleus      HybridCount     2.58623     ⋯
#    6 │ sep1WTymEGFP-hph            1  Nucleus      HybridCount     1.93019
#    7 │ sep1WTymEGFP-hph            1  Nucleus      HybridCount     0.0
#    8 │ sep1WTymEGFP-hph            1  Nucleus      HybridCount     0.0
#    9 │ sep1WTymEGFP-hph            1  Nucleus      HybridCount     0.0         ⋯
#   10 │ sep1WTymEGFP-hph            1  Nucleus      HybridCount     2.0
#   11 │ sep1WTymEGFP-hph            1  Nucleus      HybridCount     3.0
#   ⋮  │        ⋮               ⋮            ⋮            ⋮           ⋮          ⋱
#  580 │ sep1WTymEGFP-hph            1  Nucleus      HybridCount     1.0
#  581 │ sep1WTymEGFP-hph            1  Nucleus      HybridCount     0.0         ⋯
#  582 │ sep1WTymEGFP-hph            1  Nucleus      HybridCount     1.74285
#  583 │ sep1WTymEGFP-hph            1  Nucleus      HybridCount     2.25264
#  584 │ sep1WTymEGFP-hph            1  Nucleus      HybridCount     3.05767
#  585 │ sep1WTymEGFP-hph            1  Nucleus      HybridCount     1.0         ⋯
#  586 │ sep1WTymEGFP-hph            1  Nucleus      HybridCount     3.12764
#  587 │ sep1WTymEGFP-hph            1  Nucleus      HybridCount     1.0
#  588 │ sep1WTymEGFP-hph            1  Nucleus      HybridCount     1.0
#  589 │ sep1WTymEGFP-hph            1  Nucleus      HybridCount     2.0         ⋯
#                                                    1 column and 568 rows omitted

# %% [markdown]
# If the moments I find differ from this then I know there's an issue! Let's collect the columns corresponding to the nuclear and cytoplasmic volumes and **counts** respectively.

# %%
names(dfsC[1])
# Out:
# 6-element Vector{String}:
#  "gene"
#  "NucleiCount"
#  "Compartment"
#  "CountMethod"
#  "RNAperCell"
#  "Cell_Length_um"

# %%
n_vols = [dfsN[i][!,:Cell_Length_um] for i in 1:length(dfsN)]
c_vols = [dfsC[i][!,:Cell_Length_um] for i in 1:length(dfsN)]
n_ints = [dfsN[i][!,:RNAperCell] for i in 1:length(dfsN)]
c_ints = [dfsC[i][!,:RNAperCell] for i in 1:length(dfsN)];

# %%
Ns = [length(c_ints[i]) for i in 1:length(dfsN)]
# Out:
# 7-element Vector{Int64}:
#  1382
#  1425
#  2155
#  3064
#  1142
#  2660
#   589

# %% [markdown]
# For the linear model fits we use the Julia package GLM. This is a very convenient and fast way to construct linear models.

# %%
using GLM

# %% [markdown]
# Perform the linear model fits. Note in the below that our fitting parameters are stored in `npar` and `cpar` in the order `[intercept, gradient]`.

# %%
nlms = [lm(@formula(RNAperCell ~ Cell_Length_um), dfsN[i]) for i in 1:length(dfsN)]
npars = [coef(nlms[i]) for i in 1:length(dfsN)]
cs = hcat(npars...)[1,:]; ds = hcat(npars...)[2,:]
clms = [lm(@formula(RNAperCell ~ Cell_Length_um), dfsC[i]) for i in 1:length(dfsN)]
cpars = [coef(clms[i]) for i in 1:length(dfsN)]
as = hcat(cpars...)[1,:]; bs = hcat(cpars...)[2,:]
# Out:
# 7-element Vector{Float64}:
#  0.30641154269660803
#  1.8515975640701994
#  0.4467318017401305
#  0.4701437266812446
#  0.3841590645274558
#  0.5616545131813088
#  0.32100864052858896

# %% [markdown]
# A quick look at the linear model fit itself will tell us some properties of the fit.

# %%
clms[1]
# Out:
# StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Vector{Float64}}, GLM.DensePredChol{Float64, LinearAlgebra.CholeskyPivoted{Float64, Matrix{Float64}, Vector{Int64}}}}, Matrix{Float64}}
#
# RNAperCell ~ 1 + Cell_Length_um
#
# Coefficients:
# ────────────────────────────────────────────────────────────────────────────
#                     Coef.  Std. Error      t  Pr(>|t|)  Lower 95%  Upper 95%
# ────────────────────────────────────────────────────────────────────────────
# (Intercept)     -1.05398    0.167717   -6.28    <1e-09  -1.38299   -0.724971
# Cell_Length_um   0.306412   0.0181241  16.91    <1e-57   0.270858   0.341965
# ────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# Now, to construct the volume corrected moments we first need to know the mean values for the volumes and intensities. Collect these from the data.

# %%
n_vol_avgs = [mean(n_vols[i]) for i in 1:length(dfsN)]
c_vol_avgs = [mean(c_vols[i]) for i in 1:length(dfsN)]
n_avgs = [mean(n_ints[i]) for i in 1:length(dfsN)]
c_avgs = [mean(c_ints[i]) for i in 1:length(dfsN)]
# Out:
# 7-element Vector{Float64}:
#   1.7418154870810418
#  17.88112607482035
#   2.852519100296984
#   2.8969133310819193
#   4.400263520751314
#   3.5203706452932333
#   5.4255329481341255

# %% [markdown]
# Note that even the means of the cytoplasmic can vary quite significantly between the replicates. As can the observed mean cell volumes in each experiment.

# %% [markdown]
# We know theoretically that to first order volume corrections to the means are nil. Let's just clarify this.

# %%
ds
# Out:
# 7-element Vector{Float64}:
#   0.02350000731645132
#   0.10975205337956317
#   0.03694738131099742
#   0.05484416798638201
#   0.012737215226410688
#   0.025089497537933433
#  -0.08352816039633168

# %%
vc_mean_ns = [cs[i] + n_vol_avgs[i]*ds[i] for i in 1:length(dfsN)]
vc_mean_cs = [as[i] + c_vol_avgs[i]*bs[i] for i in 1:length(dfsN)]
# vc_mean_cs = a + c_vol_avg*b
# Out:
# 7-element Vector{Float64}:
#   1.741815487081041
#  17.881126074820344
#   2.8525191002969827
#   2.896913331081918
#   4.400263520751314
#   3.520370645293235
#   5.425532948134125

# %%
μ2Ωs = [moment(n_vols[i], 2, n_vol_avgs[i]) for i in 1:length(dfsN)];

# %%
μ11s = [(sum(n_ints[i].*c_ints[i])/length(n_ints[i])) - n_avgs[i]*c_avgs[i] for i in 1:length(dfsN)]
μ11s_i = [μ11s[i] - ds[i]*bs[i] * μ2Ωs[i] for i in 1:length(dfsN)]
# Out:
# 7-element Vector{Float64}:
#  -0.1082124373872857
#  -0.707996823009487
#  -0.0959415795120469
#  -0.2757087262078865
#  -0.14822508297312428
#  -0.08644233254249924
#  -0.22525487353393797

# %% [markdown]
# # Now for the bootstraps

# %%
function bootstrap_samps(n_pop,c_pop,v_pop,N)
    if length(n_pop)!=length(c_pop)
        return error("args must be the same length")
    end
    # make an array of all the indices
    all_inds = collect(1:1:length(n_pop))
    samps = [sort(sample(all_inds,N)) for i in 1:5000]
    n_samps = [n_pop[samps[i]] for i in 1:5000]
    c_samps = [c_pop[samps[i]] for i in 1:5000]
    v_samps = [v_pop[samps[i]] for i in 1:5000]
    cvs = zeros(5000)
    # for each bootstrapped sample we now need the vol corr moments.
    for j in 1:5000
        ns = n_samps[j]; cs = c_samps[j]; vs = v_samps[j];
        dftemp = DataFrame(vol=vs,n=ns,c=cs);
        nlm = lm(@formula(n ~ vol), dftemp);
        npars = coef(nlm); c = npars[1]; d = npars[2];
        clm = lm(@formula(c ~ vol), dftemp);
        cpars = coef(clm); a = cpars[1]; b = cpars[2];
        navg = mean(ns); cavg = mean(cs); vavg = mean(vs);
        μ2Ω = moment(vs, 2, vavg);
        μ11s = (sum(ns.*cs)/length(ns)) - navg*cavg;
        cvi = μ11s - d*b * μ2Ω
        cvs[j] = cvi;
    end
    return cvs
end
ti = 3
test = bootstrap_samps(n_ints[3],c_ints[3],n_vols[3],Ns[3]);

# %% [markdown]
# ## Can now see the bootstrapped stds for everything

# %%
bssamps = [bootstrap_samps(n_ints[i],c_ints[i],n_vols[i],Ns[i]) for i in 1:length(n_ints)];

# %%
histogram(bssamps[1], legend = :none)

# %%
histogram(bssamps[2],title = "rpb1: bootstrapped covariances", legend = :none)

# %%
cvars = [var(bssamps[i]) for i in 1:length(n_ints)]
cvars_std = cvars.^(1/2)
# Out:
# 7-element Vector{Float64}:
#  0.015125522485011584
#  0.16238769966902386
#  0.015837533839068545
#  0.024789274011648328
#  0.035474550108510125
#  0.017352222423547982
#  0.09094083279073946

# %%
limits_cvars = [[μ11s_i[i]-cvars_std[i],μ11s_i[i],μ11s_i[i]+cvars_std[i]] for i in 1:length(n_ints)]
# Out:
# 7-element Vector{Vector{Float64}}:
#  [-0.12333795987229729, -0.1082124373872857, -0.09308691490227411]
#  [-0.8703845226785109, -0.707996823009487, -0.5456091233404631]
#  [-0.11177911335111546, -0.0959415795120469, -0.08010404567297835]
#  [-0.3004980002195348, -0.2757087262078865, -0.2509194521962382]
#  [-0.1836996330816344, -0.14822508297312428, -0.11275053286461416]
#  [-0.10379455496604723, -0.08644233254249924, -0.06909011011895125]
#  [-0.3161957063246774, -0.22525487353393797, -0.13431404074319853]

# %%
using StatsPlots

# %%
genes
# Out:
# 10-element Vector{String31}:
#  "cdc13endog"
#  "mad1endog"
#  "rpb1endog"
#  "mad1WTymEGFP"
#  "mad2WTymEGFP"
#  "bub1WTymEGFP"
#  "mad3WTymEGFP"
#  "sep1WTymEGFP-hph"
#  "SPAC27D709cWTymEGFP-hph"
#  "SPAC2H1001WTymEGFP-hph"

# %%
sel_genes = genes[[2,3,4,5,6,7,8]];

# %%
ind_dfs = []
for i in 1:length(sel_genes)
    gnstr = convert(CategoricalArray{String,1,UInt32}, [sel_genes[i] for j in 1:5000])
    ind_df = DataFrame(Covar = bssamps[i], Gene = gnstr)
    push!(ind_dfs,ind_df)
end

# %%
ind_dfs
# Out:
# 7-element Vector{Any}:
#  5000×2 DataFrame
#   Row │ Covar       Gene
#       │ Float64     Cat…
# ──────┼───────────────────────
#     1 │ -0.0921861  mad1endog
#     2 │ -0.0951342  mad1endog
#     3 │ -0.116607   mad1endog
#     4 │ -0.0959176  mad1endog
#     5 │ -0.126343   mad1endog
#     6 │ -0.115302   mad1endog
#     7 │ -0.10409    mad1endog
#     8 │ -0.0894996  mad1endog
#     9 │ -0.100622   mad1endog
#    10 │ -0.0798406  mad1endog
#    11 │ -0.106758   mad1endog
#   ⋮   │     ⋮           ⋮
#  4991 │ -0.0821675  mad1endog
#  4992 │ -0.109636   mad1endog
#  4993 │ -0.110917   mad1endog
#  4994 │ -0.0995161  mad1endog
#  4995 │ -0.0800857  mad1endog
#  4996 │ -0.109743   mad1endog
#  4997 │ -0.102921   mad1endog
#  4998 │ -0.125077   mad1endog
#  4999 │ -0.130885   mad1endog
#  5000 │ -0.104583   mad1endog
#              4979 rows omitted
#  5000×2 DataFrame
#   Row │ Covar      Gene
#       │ Float64    Cat…
# ──────┼──────────────────────
#     1 │ -0.758776  rpb1endog
#     2 │ -0.834785  rpb1endog
#     3 │ -0.963594  rpb1endog
#     4 │ -0.5214    rpb1endog
#     5 │ -0.713602  rpb1endog
#     6 │ -0.831667  rpb1endog
#     7 │ -0.833788  rpb1endog
#     8 │ -0.648333  rpb1endog
#     9 │ -0.601824  rpb1endog
#    10 │ -0.61094   rpb1endog
#    11 │ -0.715375  rpb1endog
#   ⋮   │     ⋮          ⋮
#  4991 │ -0.55428   rpb1endog
#  4992 │ -0.684117  rpb1endog
#  4993 │ -0.554582  rpb1endog
#  4994 │ -0.783479  rpb1endog
#  4995 │ -0.843777  rpb1endog
#  4996 │ -0.383277  rpb1endog
#  4997 │ -0.841232  rpb1endog
#  4998 │ -0.95308   rpb1endog
#  4999 │ -0.736996  rpb1endog
#  5000 │ -0.549218  rpb1endog
#             4979 rows omitted
#  5000×2 DataFrame
#   Row │ Covar       Gene
#       │ Float64     Cat…
# ──────┼──────────────────────────
#     1 │ -0.10261    mad1WTymEGFP
#     2 │ -0.0703698  mad1WTymEGFP
#     3 │ -0.0750366  mad1WTymEGFP
#     4 │ -0.0781199  mad1WTymEGFP
#     5 │ -0.0898554  mad1WTymEGFP
#     6 │ -0.0545067  mad1WTymEGFP
#     7 │ -0.0705456  mad1WTymEGFP
#     8 │ -0.090972   mad1WTymEGFP
#     9 │ -0.0895356  mad1WTymEGFP
#    10 │ -0.102918   mad1WTymEGFP
#    11 │ -0.0924791  mad1WTymEGFP
#   ⋮   │     ⋮            ⋮
#  4991 │ -0.0982665  mad1WTymEGFP
#  4992 │ -0.0794643  mad1WTymEGFP
#  4993 │ -0.0842892  mad1WTymEGFP
#  4994 │ -0.075235   mad1WTymEGFP
#  4995 │ -0.115281   mad1WTymEGFP
#  4996 │ -0.0812121  mad1WTymEGFP
#  4997 │ -0.0980768  mad1WTymEGFP
#  4998 │ -0.0797379  mad1WTymEGFP
#  4999 │ -0.106631   mad1WTymEGFP
#  5000 │ -0.10072    mad1WTymEGFP
#                 4979 rows omitted
#  5000×2 DataFrame
#   Row │ Covar      Gene
#       │ Float64    Cat…
# ──────┼─────────────────────────
#     1 │ -0.236868  mad2WTymEGFP
#     2 │ -0.276014  mad2WTymEGFP
#     3 │ -0.232448  mad2WTymEGFP
#     4 │ -0.269529  mad2WTymEGFP
#     5 │ -0.30308   mad2WTymEGFP
#     6 │ -0.28755   mad2WTymEGFP
#     7 │ -0.304728  mad2WTymEGFP
#     8 │ -0.290784  mad2WTymEGFP
#     9 │ -0.276464  mad2WTymEGFP
#    10 │ -0.270009  mad2WTymEGFP
#    11 │ -0.294322  mad2WTymEGFP
#   ⋮   │     ⋮           ⋮
#  4991 │ -0.307465  mad2WTymEGFP
#  4992 │ -0.298483  mad2WTymEGFP
#  4993 │ -0.27004   mad2WTymEGFP
#  4994 │ -0.252773  mad2WTymEGFP
#  4995 │ -0.281235  mad2WTymEGFP
#  4996 │ -0.258933  mad2WTymEGFP
#  4997 │ -0.271143  mad2WTymEGFP
#  4998 │ -0.236004  mad2WTymEGFP
#  4999 │ -0.326274  mad2WTymEGFP
#  5000 │ -0.25198   mad2WTymEGFP
#                4979 rows omitted
#  5000×2 DataFrame
#   Row │ Covar      Gene
#       │ Float64    Cat…
# ──────┼─────────────────────────
#     1 │ -0.16776   bub1WTymEGFP
#     2 │ -0.141943  bub1WTymEGFP
#     3 │ -0.130515  bub1WTymEGFP
#     4 │ -0.147253  bub1WTymEGFP
#     5 │ -0.173936  bub1WTymEGFP
#     6 │ -0.192445  bub1WTymEGFP
#     7 │ -0.174664  bub1WTymEGFP
#     8 │ -0.132053  bub1WTymEGFP
#     9 │ -0.124763  bub1WTymEGFP
#    10 │ -0.1489    bub1WTymEGFP
#    11 │ -0.170913  bub1WTymEGFP
#   ⋮   │     ⋮           ⋮
#  4991 │ -0.088245  bub1WTymEGFP
#  4992 │ -0.185682  bub1WTymEGFP
#  4993 │ -0.136875  bub1WTymEGFP
#  4994 │ -0.111701  bub1WTymEGFP
#  4995 │ -0.158973  bub1WTymEGFP
#  4996 │ -0.178369  bub1WTymEGFP
#  4997 │ -0.110612  bub1WTymEGFP
#  4998 │ -0.17758   bub1WTymEGFP
#  4999 │ -0.154518  bub1WTymEGFP
#  5000 │ -0.15203   bub1WTymEGFP
#                4979 rows omitted
#  5000×2 DataFrame
#   Row │ Covar       Gene
#       │ Float64     Cat…
# ──────┼──────────────────────────
#     1 │ -0.0797754  mad3WTymEGFP
#     2 │ -0.10651    mad3WTymEGFP
#     3 │ -0.092453   mad3WTymEGFP
#     4 │ -0.107409   mad3WTymEGFP
#     5 │ -0.0791936  mad3WTymEGFP
#     6 │ -0.0662167  mad3WTymEGFP
#     7 │ -0.0647536  mad3WTymEGFP
#     8 │ -0.0843012  mad3WTymEGFP
#     9 │ -0.0862423  mad3WTymEGFP
#    10 │ -0.0987504  mad3WTymEGFP
#    11 │ -0.0915415  mad3WTymEGFP
#   ⋮   │     ⋮            ⋮
#  4991 │ -0.0674417  mad3WTymEGFP
#  4992 │ -0.0951387  mad3WTymEGFP
#  4993 │ -0.0698696  mad3WTymEGFP
#  4994 │ -0.083162   mad3WTymEGFP
#  4995 │ -0.0889632  mad3WTymEGFP
#  4996 │ -0.0719458  mad3WTymEGFP
#  4997 │ -0.101044   mad3WTymEGFP
#  4998 │ -0.113677   mad3WTymEGFP
#  4999 │ -0.0767163  mad3WTymEGFP
#  5000 │ -0.0898667  mad3WTymEGFP
#                 4979 rows omitted
#  5000×2 DataFrame
#   Row │ Covar       Gene
#       │ Float64     Cat…
# ──────┼──────────────────────────────
#     1 │ -0.257971   sep1WTymEGFP-hph
#     2 │ -0.125401   sep1WTymEGFP-hph
#     3 │ -0.262502   sep1WTymEGFP-hph
#     4 │ -0.22768    sep1WTymEGFP-hph
#     5 │ -0.268539   sep1WTymEGFP-hph
#     6 │ -0.234657   sep1WTymEGFP-hph
#     7 │ -0.200925   sep1WTymEGFP-hph
#     8 │ -0.252565   sep1WTymEGFP-hph
#     9 │ -0.217284   sep1WTymEGFP-hph
#    10 │ -0.135924   sep1WTymEGFP-hph
#    11 │ -0.288876   sep1WTymEGFP-hph
#   ⋮   │     ⋮              ⋮
#  4991 │ -0.334217   sep1WTymEGFP-hph
#  4992 │ -0.152789   sep1WTymEGFP-hph
#  4993 │ -0.135326   sep1WTymEGFP-hph
#  4994 │ -0.109889   sep1WTymEGFP-hph
#  4995 │ -0.16961    sep1WTymEGFP-hph
#  4996 │ -0.172793   sep1WTymEGFP-hph
#  4997 │ -0.0741423  sep1WTymEGFP-hph
#  4998 │ -0.0645094  sep1WTymEGFP-hph
#  4999 │ -0.239069   sep1WTymEGFP-hph
#  5000 │ -0.470527   sep1WTymEGFP-hph
#                     4979 rows omitted

# %%
using CategoricalArrays

# %%
convert(CategoricalArray{String,1,UInt32},["rt"])
# Out:
# 1-element CategoricalArray{String,1,UInt32}:
#  "rt"

# %%
comb_dfs = vcat(ind_dfs...)
# Out:
# 35000×2 DataFrame
#    Row │ Covar       Gene
#        │ Float64     Cat…
# ───────┼──────────────────────────────
#      1 │ -0.0921861  mad1endog
#      2 │ -0.0951342  mad1endog
#      3 │ -0.116607   mad1endog
#      4 │ -0.0959176  mad1endog
#      5 │ -0.126343   mad1endog
#      6 │ -0.115302   mad1endog
#      7 │ -0.10409    mad1endog
#      8 │ -0.0894996  mad1endog
#      9 │ -0.100622   mad1endog
#     10 │ -0.0798406  mad1endog
#     11 │ -0.106758   mad1endog
#    ⋮   │     ⋮              ⋮
#  34991 │ -0.334217   sep1WTymEGFP-hph
#  34992 │ -0.152789   sep1WTymEGFP-hph
#  34993 │ -0.135326   sep1WTymEGFP-hph
#  34994 │ -0.109889   sep1WTymEGFP-hph
#  34995 │ -0.16961    sep1WTymEGFP-hph
#  34996 │ -0.172793   sep1WTymEGFP-hph
#  34997 │ -0.0741423  sep1WTymEGFP-hph
#  34998 │ -0.0645094  sep1WTymEGFP-hph
#  34999 │ -0.239069   sep1WTymEGFP-hph
#  35000 │ -0.470527   sep1WTymEGFP-hph
#                     34979 rows omitted

# %%
@df comb_dfs violin(:Gene,:Covar,marker=(0.2,cpal[1],stroke(0)), grid = false, minorgrid = false, legend = :none, 
    xrotation = 45, color = cpal[6])
@df comb_dfs boxplot!(:Gene,:Covar,marker=(0.2,cpal[1],stroke(0)),alpha = 0.5)
plot!([0,1000],[0,0], xlims = [0,8], ylabel = "Bootstrapped Covariance", color = cpal[1], linestyle = :dash)
plot!(bottom_margin = 5mm)
# savefig("./violin-covar-bootstrap2.pdf")

# %% [markdown]
# ## Now for the TSL data and comparison to non-TSL results

# %%
df2 = DataFrame(CSV.File("./mad1WTGFP/TSlabeling_IndRNA_wide_220615_without2rpb1outliers_3DNucExpand_withColDescription.csv"));

# %%
names(df2)
# Out:
# 16-element Vector{String}:
#  "sampleID"
#  "gene"
#  "probe"
#  "strain"
#  "imageID"
#  "CellNo"
#  "NucleiCount"
#  "Compartment"
#  "CountMethod"
#  "ClassMethod"
#  "RNAperCell"
#  "Cell_Pseudovol_um"
#  "Cell_Area_um"
#  "Cell_Length_um"
#  "Cell_Width_um"
#  "Nuc_Vol_um"

# %%
df2 = df2[:,[:gene,:NucleiCount,:Compartment,:CountMethod,:RNAperCell,:Cell_Length_um]];

# %%
# filter NucleiCount = 1
dfa2 = subset(df2,:NucleiCount => n -> n.==1, :CountMethod => m -> m.=="HybridCount")
# make cyto and nuc table separately.
dfcyto2 = subset(dfa2, :Compartment=>c->c.=="Cytoplasm")
dfnuc2 = subset(dfa2, :Compartment=>c->c.=="MatureNuclear")
# separate the 7 different genes
dfsN2 = []; dfsC2 = [];
genes = unique(dfa2[!,:gene])
# add each to the vectors
for i in 1:length(genes)
    dftempN2 = subset(dfnuc2, :gene=>S->S.==genes[i])
    dftempC2 = subset(dfcyto2, :gene=>S->S.==genes[i])
    push!(dfsN2,dftempN2)
    push!(dfsC2,dftempC2)
end

# %%
dfsC2;

# %%
names(dfsC2[1])
# Out:
# 6-element Vector{String}:
#  "gene"
#  "NucleiCount"
#  "Compartment"
#  "CountMethod"
#  "RNAperCell"
#  "Cell_Length_um"

# %%
n_vols2 = [dfsN2[i][!,:Cell_Length_um] for i in 1:length(dfsN2)]
c_vols2 = [dfsC2[i][!,:Cell_Length_um] for i in 1:length(dfsN2)]
n_ints2 = [dfsN2[i][!,:RNAperCell] for i in 1:length(dfsN2)]
c_ints2 = [dfsC2[i][!,:RNAperCell] for i in 1:length(dfsN2)]
# Out:
# 2-element Vector{Vector{Float64}}:
#  [2.0, 2.0, 3.0, 0.0, 0.0, 2.685623568, 2.0, 2.0, 1.680440637, 2.0  …  3.0, 2.0, 0.0, 0.0, 2.0, 1.0, 1.0, 1.0, 0.0, 1.0]
#  [17.0, 16.99167959, 7.649634027, 20.0, 17.0, 15.0, 12.0, 12.0, 8.0, 14.0  …  15.04135752, 10.0, 13.70807153, 14.0, 16.0, 19.44798512, 20.8647729, 15.64741647, 17.68226133, 25.67076803]

# %%
Ns2 = [length(n_ints2[i]) for i in 1:length(dfsN2)]
# Out:
# 2-element Vector{Int64}:
#  884
#  921

# %% [markdown]
# Perform the linear model fits. Note in the below that our fitting parameters are stored in `npar` and `cpar` in the order `[intercept, gradient]`.

# %%
nlms2 = [lm(@formula(RNAperCell ~ Cell_Length_um), dfsN2[i]) for i in 1:length(dfsN2)]
npars2 = [coef(nlms2[i]) for i in 1:length(dfsN2)]
cs2 = hcat(npars2...)[1,:]; ds2 = hcat(npars2...)[2,:]
clms2 = [lm(@formula(RNAperCell ~ Cell_Length_um), dfsC2[i]) for i in 1:length(dfsN2)]
cpars2 = [coef(clms2[i]) for i in 1:length(dfsN2)]
as2 = hcat(cpars2...)[1,:]; bs2 = hcat(cpars2...)[2,:]
# Out:
# 2-element Vector{Float64}:
#  0.33056907642487837
#  1.6575398409442

# %% [markdown]
# A quick look at the linear model fit itself will tell us some properties of the fit.

# %%
clms2[1]
# Out:
# StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Vector{Float64}}, GLM.DensePredChol{Float64, LinearAlgebra.CholeskyPivoted{Float64, Matrix{Float64}, Vector{Int64}}}}, Matrix{Float64}}
#
# RNAperCell ~ 1 + Cell_Length_um
#
# Coefficients:
# ────────────────────────────────────────────────────────────────────────────
#                     Coef.  Std. Error      t  Pr(>|t|)  Lower 95%  Upper 95%
# ────────────────────────────────────────────────────────────────────────────
# (Intercept)     -1.2094     0.188498   -6.42    <1e-09   -1.57935  -0.839441
# Cell_Length_um   0.330569   0.0203598  16.24    <1e-51    0.29061   0.370528
# ────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# Now, to construct the volume corrected moments we first need to know the mean values for the volumes and intensities. Collect these from the data.

# %%
n_vol_avgs2 = [mean(n_vols2[i]) for i in 1:length(dfsN2)]
c_vol_avgs2 = [mean(c_vols2[i]) for i in 1:length(dfsN2)]
n_avgs2 = [mean(n_ints2[i]) for i in 1:length(dfsN2)]
c_avgs2 = [mean(c_ints2[i]) for i in 1:length(dfsN2)]
# Out:
# 2-element Vector{Float64}:
#   1.798827173020362
#  16.337517424938106

# %% [markdown]
# Note that even the means of the cytoplasmic can vary quite significantly between the replicates. As can the observed mean cell volumes in each experiment.

# %% [markdown]
# We know theoretically that to first order volume corrections to the means are nil. Let's just clarify this.

# %%
bs2
# Out:
# 2-element Vector{Float64}:
#  0.33056907642487837
#  1.6575398409442

# %%
vc_mean_ns2 = [cs2[i] + n_vol_avgs2[i]*ds2[i] for i in 1:length(dfsN2)]
vc_mean_cs2 = [as2[i] + c_vol_avgs2[i]*bs2[i] for i in 1:length(dfsN2)]
# vc_mean_cs = a + c_vol_avg*b
# Out:
# 2-element Vector{Float64}:
#   1.7988271730203629
#  16.33751742493811

# %%
μ2Ωs2 = [moment(n_vols2[i], 2, n_vol_avgs2[i]) for i in 1:length(dfsN2)];

# %%
μ11s2 = [(sum(n_ints2[i].*c_ints2[i])/length(n_ints2[i])) - n_avgs2[i]*c_avgs2[i] for i in 1:length(dfsN2)]
μ11s2_i = [μ11s2[i] - ds2[i]*bs2[i] * μ2Ωs2[i] for i in 1:length(dfsN2)]
# Out:
# 2-element Vector{Float64}:
#  -0.04645859070658411
#  -0.39520822902829844

# %% [markdown]
# Now for the bootstraps

# %%
bssamps2 = [bootstrap_samps(n_ints2[i],c_ints2[i],n_vols2[i],Ns2[i]) for i in 1:length(n_ints2)];

# %%
histogram(bssamps2[1], legend = :none)

# %%
histogram(bssamps2[2],title = "rpb1: bootstrapped covariances", legend = :none)

# %%
cvars2 = [var(bssamps2[i]) for i in 1:length(n_ints2)]
cvars2_std = cvars2.^(1/2)
# Out:
# 2-element Vector{Float64}:
#  0.013359618906746737
#  0.1324274045283174

# %%
limits_cvars2 = [[μ11s2_i[i]-cvars2_std[i],μ11s2_i[i],μ11s2_i[i]+cvars2_std[i]] for i in 1:length(n_ints2)]
# Out:
# 2-element Vector{Vector{Float64}}:
#  [-0.05981820961333085, -0.04645859070658411, -0.033098971799837375]
#  [-0.5276356335566158, -0.39520822902829844, -0.2627808244999811]

# %%
sel_genes2a = unique(df2[!,:gene])
sel_genes2 = [join([sel_genes2a[j]," (TSL)"]) for j in 1:2]
# Out:
# 2-element Vector{String}:
#  "mad1endog (TSL)"
#  "rpb1endog (TSL)"

# %%
ind_dfs2 = []
for i in 1:2
    gnstr = convert(CategoricalArray{String,1,UInt32}, [sel_genes2[i] for j in 1:5000])
    ind_df2 = DataFrame(Covar = bssamps2[i], Gene = gnstr)
    push!(ind_dfs2,ind_df2)
end

# %%
ind_dfs2
# Out:
# 2-element Vector{Any}:
#  5000×2 DataFrame
#   Row │ Covar       Gene
#       │ Float64     Cat…
# ──────┼─────────────────────────────
#     1 │ -0.0590813  mad1endog (TSL)
#     2 │ -0.0650999  mad1endog (TSL)
#     3 │ -0.0370848  mad1endog (TSL)
#     4 │ -0.0485181  mad1endog (TSL)
#     5 │ -0.0561154  mad1endog (TSL)
#     6 │ -0.0372793  mad1endog (TSL)
#     7 │ -0.0425186  mad1endog (TSL)
#     8 │ -0.0576075  mad1endog (TSL)
#     9 │ -0.0285729  mad1endog (TSL)
#    10 │ -0.0454531  mad1endog (TSL)
#    11 │ -0.0616579  mad1endog (TSL)
#   ⋮   │     ⋮              ⋮
#  4991 │ -0.0401925  mad1endog (TSL)
#  4992 │ -0.0624613  mad1endog (TSL)
#  4993 │ -0.0408634  mad1endog (TSL)
#  4994 │ -0.042901   mad1endog (TSL)
#  4995 │ -0.036738   mad1endog (TSL)
#  4996 │ -0.0561981  mad1endog (TSL)
#  4997 │ -0.0143954  mad1endog (TSL)
#  4998 │ -0.0364812  mad1endog (TSL)
#  4999 │ -0.0544457  mad1endog (TSL)
#  5000 │ -0.0124404  mad1endog (TSL)
#                    4979 rows omitted
#  5000×2 DataFrame
#   Row │ Covar      Gene
#       │ Float64    Cat…
# ──────┼────────────────────────────
#     1 │ -0.082982  rpb1endog (TSL)
#     2 │ -0.299604  rpb1endog (TSL)
#     3 │ -0.292645  rpb1endog (TSL)
#     4 │ -0.312672  rpb1endog (TSL)
#     5 │ -0.399178  rpb1endog (TSL)
#     6 │ -0.463604  rpb1endog (TSL)
#     7 │ -0.347836  rpb1endog (TSL)
#     8 │ -0.22477   rpb1endog (TSL)
#     9 │ -0.264414  rpb1endog (TSL)
#    10 │ -0.171199  rpb1endog (TSL)
#    11 │ -0.395571  rpb1endog (TSL)
#   ⋮   │     ⋮             ⋮
#  4991 │ -0.289037  rpb1endog (TSL)
#  4992 │ -0.433461  rpb1endog (TSL)
#  4993 │ -0.298247  rpb1endog (TSL)
#  4994 │ -0.171709  rpb1endog (TSL)
#  4995 │ -0.448889  rpb1endog (TSL)
#  4996 │ -0.366889  rpb1endog (TSL)
#  4997 │ -0.515526  rpb1endog (TSL)
#  4998 │ -0.310246  rpb1endog (TSL)
#  4999 │ -0.214855  rpb1endog (TSL)
#  5000 │ -0.274398  rpb1endog (TSL)
#                   4979 rows omitted

# %%
comb_dfs2 = vcat(ind_dfs2[1],ind_dfs[1],ind_dfs2[2],ind_dfs[2])
# Out:
# 20000×2 DataFrame
#    Row │ Covar       Gene
#        │ Float64     Cat…
# ───────┼─────────────────────────────
#      1 │ -0.0590813  mad1endog (TSL)
#      2 │ -0.0650999  mad1endog (TSL)
#      3 │ -0.0370848  mad1endog (TSL)
#      4 │ -0.0485181  mad1endog (TSL)
#      5 │ -0.0561154  mad1endog (TSL)
#      6 │ -0.0372793  mad1endog (TSL)
#      7 │ -0.0425186  mad1endog (TSL)
#      8 │ -0.0576075  mad1endog (TSL)
#      9 │ -0.0285729  mad1endog (TSL)
#     10 │ -0.0454531  mad1endog (TSL)
#     11 │ -0.0616579  mad1endog (TSL)
#    ⋮   │     ⋮              ⋮
#  19991 │ -0.55428    rpb1endog
#  19992 │ -0.684117   rpb1endog
#  19993 │ -0.554582   rpb1endog
#  19994 │ -0.783479   rpb1endog
#  19995 │ -0.843777   rpb1endog
#  19996 │ -0.383277   rpb1endog
#  19997 │ -0.841232   rpb1endog
#  19998 │ -0.95308    rpb1endog
#  19999 │ -0.736996   rpb1endog
#  20000 │ -0.549218   rpb1endog
#                    19979 rows omitted

# %%
@df comb_dfs2 violin(:Gene,:Covar,marker=(0.2,cpal[1],stroke(0)), grid = false, minorgrid = false, legend = :none, 
    xrotation = 45, color = cpal[6])
@df comb_dfs2 boxplot!(:Gene,:Covar,marker=(0.2,cpal[1],stroke(0)),alpha = 0.5)
plot!([0,1000],[0,0], xlims = [0,5], ylabel = "Bootstrapped Covariance", color = cpal[1], linestyle = :dash)
plot!(bottom_margin = 5mm)
# savefig("./violin-covar-bootstrap2.pdf")
